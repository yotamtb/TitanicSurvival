# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
passenger_data = pd.read_csv('../data/train.csv', index_col='PassengerId')

# %%
passenger_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
columns_set = ['Sex','Survived','Age']

# %%
passenger_data[columns_set][passenger_data['Age']<=10]
# Out:
#                 Sex  Survived   Age
# PassengerId
# 8              male         0  2.00
# 11           female         1  4.00
# 17             male         0  2.00
# 25           female         0  8.00
# 44           female         1  3.00
# ...             ...       ...   ...
# 828            male         1  1.00
# 832            male         1  0.83
# 851            male         0  4.00
# 853          female         0  9.00
# 870            male         1  4.00
#
# [64 rows x 3 columns]

# %%
survived_by_sex = passenger_data[columns_set][passenger_data['Age']<=10]

# %%
grouping = survived_by_sex.groupby(columns_set)

# %%
grouping['Survived'].agg(np.size)
# Out:
# Sex     Survived  Age
# female  0         2.00     4
#                   3.00     1
#                   6.00     1
#                   8.00     1
#                   9.00     4
#                   10.00    1
#         1         0.75     2
#                   1.00     2
#                   2.00     2
#                   3.00     1
#                   4.00     5
#                   5.00     4
#                   6.00     1
#                   7.00     1
#                   8.00     1
# male    0         1.00     2
#                   2.00     3
#                   4.00     3
#                   7.00     2
#                   8.00     1
#                   9.00     2
#                   10.00    1
#         1         0.42     1
#                   0.67     1
#                   0.83     2
#                   0.92     1
#                   1.00     3
#                   2.00     1
#                   3.00     4
#                   4.00     2
#                   6.00     1
# ...

# %%
grouping.agg(np.size)
# Out:
# Sex     Survived  Age
# female  0         2.00     12
#                   3.00      3
#                   6.00      3
#                   8.00      3
#                   9.00     12
#                   10.00     3
#         1         0.75      6
#                   1.00      6
#                   2.00      6
#                   3.00      3
#                   4.00     15
#                   5.00     12
#                   6.00      3
#                   7.00      3
#                   8.00      3
# male    0         1.00      6
#                   2.00      9
#                   4.00      9
#                   7.00      6
#                   8.00      3
#                   9.00      6
#                   10.00     3
#         1         0.42      3
#                   0.67      3
#                   0.83      6
#                   0.92      3
#                   1.00      9
#                   2.00      3
#                   3.00     12
#                   4.00      6
# ...
